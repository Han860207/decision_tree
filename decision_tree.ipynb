# %%
import pandas as pd
from sklearn import tree
from sklearn import preprocessing

# %%
data = pd.read_csv('decision_tree.csv')

# %%
y = data['income']
x = data.drop(columns=['income'])

# %%
# data.info()
data.shape
# Out:
# (32561, 9)

# %%
features = pd.get_dummies(x)

# %%
features.shape
# Out:
# (32561, 102)

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy',max_depth = 3)
clf.fit(features,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.predict(features.values)
# Out:
# array([' <=50K', ' >50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype=object)

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(15,15))
tree.plot_tree(clf,
             feature_names = features.columns,
             class_names = ['<=50k','>=50k'],
             filled = True,
             rounded = True,
              fontsize=10,
              proportion=True)
# Out:
# [Text(418.5, 713.475, 'marital-status_ Married-civ-spouse <= 0.5\nentropy = 0.796\nsamples = 100.0%\nvalue = [0.759, 0.241]\nclass = <=50k'),
#  Text(209.25, 509.625, 'relationship_ Own-child <= 0.5\nentropy = 0.348\nsamples = 54.0%\nvalue = [0.935, 0.065]\nclass = <=50k'),
#  Text(104.625, 305.775, 'occupation_ Prof-specialty <= 0.5\nentropy = 0.427\nsamples = 38.7%\nvalue = [0.913, 0.087]\nclass = <=50k'),
#  Text(52.3125, 101.92499999999995, 'entropy = 0.365\nsamples = 33.5%\nvalue = [0.93, 0.07]\nclass = <=50k'),
#  Text(156.9375, 101.92499999999995, 'entropy = 0.717\nsamples = 5.2%\nvalue = [0.802, 0.198]\nclass = <=50k'),
#  Text(313.875, 305.775, 'education_ Bachelors <= 0.5\nentropy = 0.081\nsamples = 15.3%\nvalue = [0.99, 0.01]\nclass = <=50k'),
#  Text(261.5625, 101.92499999999995, 'entropy = 0.06\nsamples = 13.7%\nvalue = [0.993, 0.007]\nclass = <=50k'),
#  Text(366.1875, 101.92499999999995, 'entropy = 0.229\nsamples = 1.6%\nvalue = [0.963, 0.037]\nclass = <=50k'),
#  Text(627.75, 509.625, 'occupation_ Prof-specialty <= 0.5\nentropy = 0.992\nsamples = 46.0%\nvalue = [0.553, 0.447]\nclass = <=50k'),
#  Text(523.125, 305.775, 'occupation_ Exec-managerial <= 0.5\nentropy = 0.973\nsamples = 39.5%\nvalue = [0.596, 0.404]\nclass = <=50k'),
#  Text(470.8125, 101.92499999999995, 'entropy = 0.923\nsamples = 32.0%\nvalue = [0.662, 0.338]\nclass = <=50k'),
#  Text(575.4375, 101.92499999999995, 'entropy = 0.903\nsamples = 7.5%\nvalue = [0.318, 0.682]\nclass = >=50k'),
#  Text(732.375, 305.775, 'education_ Prof-school <= 0.5\nentropy = 0.87\nsamples = 6.5%\nvalue = [0.291, 0.709]\nclass = >=50k'),
#  Text(680.0625, 101.92499999999995, 'entropy = 0.908\nsamples = 5.5%\nvalue = [0.323, 0.677]\nclass = >=50k'),
#  Text(784.6875, 101.92499999999995, 'entropy = 0.505\nsamples = 1.0%\nvalue = [0.112, 0.888]\nclass = >=50k')]
